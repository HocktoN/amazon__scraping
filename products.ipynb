# %%
import pandas as pd
dataset = pd.read_csv('amazon.csv')
dataset
# Out:
#                                               ÜrünAdı       Fiyatı
# 0                            Apple AirPods (3. nesil)  2.986,01 TL
# 1   Apple AirPods Pro ( Yeni Nesil MagSafe Şarj Ku...  3.986,01 TL
# 2   Beats Fit Pro: Gürültü Önleme Özellikli Gerçek...  3.145,85 TL
# 3   Apple AirPods Pro ( Yeni Nesil MagSafe Şarj Ku...  3.986,01 TL
# 4                            Apple AirPods (3. nesil)  2.986,01 TL
# 5   Apple MMTN2TU/A Lightning Konnektörlü EarPods ...    300,00 TL
# 6                 Apple 3,5 mm Kulaklık Jaklı EarPods    268,73 TL
# 7   Beats Fit Pro: Gürültü Önleme Özellikli Gerçek...  3.199,00 TL
# 8   Jabra Elite 3 Kulak içi Kablosuz Bluetooth Kul...    929,00 TL
# 9   Sennheiser Momentum In-Ear i Apple Uyumlu Krom...  1.049,99 TL
# 10  Beats Flex - Tüm Gün Kullanım İçin Kablosuz Ku...  1.399,00 TL
# 11  Apple iPhone Airpods Pro Kablolu Lightning Oem...     99,90 TL
# 12  Beats Studio Buds, Gürültü Önleme Özellikli Ge...  2.196,56 TL
# ...
